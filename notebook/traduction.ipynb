# %%
from langdetect import detect
from transformers import MarianMTModel, MarianTokenizer

model_name = "Helsinki-NLP/opus-mt-fr-en"

tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

def translate_if_needed(text):
    lang = detect(text)

    print("Langue détectée :", lang)

    if lang == "en":
        inputs = tokenizer(text, return_tensors="pt", padding=True)
        outputs = model.generate(**inputs)
        return tokenizer.decode(outputs[0], skip_special_tokens=True)

    else:
        return text
# Out:
# Loading weights: 100%|██████████| 256/256 [00:00<00:00, 13258.04it/s]

# %%
translate_if_needed("Every single day I will be fighting for you with every breath in my body. I will not rest until we have delivered the strong, safe and prosperous America that our children deserve and that you deserve. This will truly be the golden age of America.")
# Out:
# Langue détectée : en
# "Chaque jour, je me bats pour vous avec chaque souffle dans mon corps. Je ne me reposerai pas avant d'avoir livré l'Amérique forte, sûre et prospère que nos enfants méritent et que vous méritez. Ce sera vraiment l'âge d'or de l'Amérique."
