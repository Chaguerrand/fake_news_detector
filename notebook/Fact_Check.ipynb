# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.tools.tavily_search import TavilySearchResults

os.environ["PYTHONIOENCODING"] = "utf-8"

load_dotenv(override=True)

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

search_tool = TavilySearchResults(max_results=5)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langgraph.prebuilt import create_react_agent

system_prompt = """Tu es un fact-checker expert.

Un modèle ML a déjà classifié l'article. Tu n'as PAS à refaire la classification.

Ton unique mission :
1. Identifie les 2-3 claims principaux de l'article
2. Utilise OBLIGATOIREMENT le tool de recherche pour trouver des sources sur chaque claim
3. Cite OBLIGATOIREMENT les URLs des sources trouvées

Format de réponse finale :
- explication basée sur les sources trouvées
- Sources trouvées :
  - [titre de l'article](URL)
  - [titre de l'article](URL)
  """

fact_checker = create_react_agent(
    llm,
    [search_tool],
    prompt=system_prompt
)
# Out:
# /var/folders/4k/_06j8ks175sgwfxfbw6lsb8m0000gn/T/ipykernel_26302/345510664.py:20: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   fact_checker = create_react_agent(

# %%
### Pour la mise en prod avec le résultat du model SVC

#label = "FAKE" if model.predict([article])[0] > 0.7 else "REAL"

#result = fact_checker.invoke({
#    "messages": [
#        ("user", f"""
#Classification ML : {label}
#
#Article : {text_to_analyze}
#        """)
#    ]
#})

# %%
result=fact_checker.invoke({
    "messages": [
        ("user", f"""
Classification ML : FAKE

Article : La multiplication par 10 des ventes de véhicules électriques depuis la COP21
        """)
    ]
})
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/fake_news_detector/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:3071, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070 try:
# -> 3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
#
# File ~/.pyenv/versions/3.10.6/envs/fake_news_detector/lib/python3.10/site-packages/google/genai/models.py:6261, in Models.generate_content(self, model, contents, config)
#    6254     logger.warning(
#    6255         'Tools at indices [%s] are not compatible with automatic function '
# ...

# %%
## Affichage notebook

# %%
from IPython.display import Markdown

last_message = result["messages"][-1]

if isinstance(last_message.content, list):
    for block in last_message.content:
        if isinstance(block, dict) and block.get("type") == "text":
            display(Markdown(block["text"]))
else:
    display(Markdown(last_message.content))
# Out:
# Le principal argument de l'article est "La multiplication par 10 des ventes de véhicules électriques depuis la COP21".
#
# Les ventes mondiales de véhicules électriques ont considérablement augmenté depuis la COP21, qui s'est tenue en décembre 2015. En 2016, les ventes mondiales étaient de 770 000 unités. En 2022, ce chiffre a atteint 10 290 000 unités, ce qui représente une multiplication par environ 13,36. Les prévisions indiquent une augmentation encore plus importante pour les années suivantes, avec 13 410 000 unités en 2023 (soit environ 17,41 fois les ventes de 2016) et des prévisions de 16 630 000 unités en 2025 (soit environ 21,59 fois les ventes de 2016). Par conséquent, l'affirmation selon laquelle les ventes ont été multipliées par 10 est non seulement exacte, mais elle est même une sous-estimation de la croissance réelle observée.
#
# Sources trouvées :
# ...
